# %%
import pandas as pd
import matplotlib.pyplot as plt

joined_data = pd.read_csv("joined_data.csv")

# %%
joined_data.head()
# Out:
#          date  us_driving  us_transit  us_walking  italy_driving  \
# 0  2020-02-01      122.32      103.42      140.80         125.55
# 1  2020-02-02       85.25       80.20       88.42         111.41
# 2  2020-02-03       98.86       96.48       92.42         100.52
# 3  2020-02-04      101.99       97.63       93.82         101.89
# 4  2020-02-05      101.77       98.26       94.52         103.77
#
#    italy_transit  italy_walking  italy_confirmed_cases  italy_suspected_cases  \
# 0         107.43         149.16                      2                      0
# 1         106.20         118.22                      2                      0
# 2          98.79         108.19                      2                      0
# 3          99.71         108.79                      2                      0
# 4          98.91         108.09                      2                      0
#
#    italy_cured_cases  italy_death_cases  us_confirmed_cases  \
# ...

# %%
driving = plt.plot( 'date', 'us_driving', data=joined_data, marker='', color='blue', linewidth=2)
plt.plot( 'date', 'italy_driving', data=joined_data, marker='', color='red', linewidth=2, linestyle='dashed', label="italy_driving")
plt.legend()
plt.xticks(rotation=90)
plt.show()
